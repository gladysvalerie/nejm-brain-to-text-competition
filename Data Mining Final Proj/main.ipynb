# %% [markdown]
# ### Final Project Data Exploration Phase

# %% [markdown]
# ##### Dataset Loading

# %%
# Imports and root path - adjust the ROOT_DIR if your data is elsewhere
import os
import h5py
import numpy as np
import pandas as pd
from pathlib import Path


ROOT_DIR = r'D:\Data Mining Final Proj\Data\t15_copyTask_neuralData\hdf5_data_final'
print('Using ROOT_DIR:', ROOT_DIR)
# Out:
# Using ROOT_DIR: D:\Data Mining Final Proj\Data\t15_copyTask_neuralData\hdf5_data_final

# %%
import h5py
import os
import pandas as pd
import numpy as np

# Initialize lists to store data for each category
train_records = []
test_records = []
validation_records = []

with os.scandir(ROOT_DIR) as path:
    for folder in path:
        if folder.is_dir():
            print(f"Processing folder: {folder.name}")
            
            with os.scandir(folder.path) as subfolder:
                for file in subfolder:
                    if file.name.endswith((".h5", ".hdf5")):
                        print(f"  Processing file: {file.name}")
                        
                        # Determine category based on file name
                        file_lower = file.name.lower()
                        if 'test' in file_lower and not 'testing' in file_lower:
                            category = 'test'
                            target_list = test_records
                        elif 'train' in file_lower:
                            category = 'train'
                            target_list = train_records
                        elif 'val' in file_lower or 'valid' in file_lower:
                            category = 'validation'
                            target_list = validation_records
                        else:
                            print(f"    Skipping file: {file.name} - not a train/test/validation file")
                            continue
                            
                        print(f"    Categorized as: {category}")
                        
                        try:
                            with h5py.File(file.path, "r") as f:
                                # List all trial folders (assuming they are groups)
                                trial_groups = [key for key in f.keys() if 'trial' in key.lower()]
                                
                                print(f"    Found {len(trial_groups)} trial groups")
                                
                                for trial in trial_groups:
                                    print(f"      Processing {trial}")
                                    trial_group = f[trial]
                                    
                                    # Extract the data we need from each trial
                                    input_features = None
                                    seq_class_ids = None
                                    transcription = None
                                    
                                    # Look for our target datasets within this trial group
                                    for dataset_name in trial_group.keys():
                                        dataset_lower = dataset_name.lower()
                                        if 'input' in dataset_lower or 'feature' in dataset_lower:
                                            print(f"        Found input features: {dataset_name}")
                                            input_features = np.array(trial_group[dataset_name])
                                        elif 'class' in dataset_lower or 'seq' in dataset_lower:
                                            print(f"        Found sequence class IDs: {dataset_name}")
                                            seq_class_ids = np.array(trial_group[dataset_name])
                                        elif 'transcript' in dataset_lower:
                                            print(f"        Found transcription: {dataset_name}")
                                            transcription = np.array(trial_group[dataset_name])
                                    
                                    # Create records for each sample in this trial
                                    # Determine how many samples we have (assuming they all have the same first dimension)
                                    num_samples = 0
                                    if input_features is not None:
                                        num_samples = input_features.shape[0]
                                    elif seq_class_ids is not None:
                                        num_samples = seq_class_ids.shape[0]
                                    elif transcription is not None:
                                        num_samples = transcription.shape[0]
                                    
                                    if num_samples == 0:
                                        print(f"        No samples found in {trial}")
                                        continue
                                    
                                    # Create records for each sample
                                    for i in range(num_samples):
                                        record = {
                                            "Category": category,
                                            "Folder": folder.name,
                                            "File": file.name,
                                            "Trial": trial,
                                            "Sample_Index": i
                                        }
                                        
                                        # Add the actual data for this sample
                                        if input_features is not None:
                                            if len(input_features.shape) > 1:
                                                record["Input_Features"] = input_features[i]
                                            else:
                                                record["Input_Features"] = input_features[i] if i < len(input_features) else None
                                                
                                        if seq_class_ids is not None:
                                            if len(seq_class_ids.shape) > 1:
                                                record["Seq_Class_IDs"] = seq_class_ids[i]
                                            else:
                                                record["Seq_Class_IDs"] = seq_class_ids[i] if i < len(seq_class_ids) else None
                                                
                                        if transcription is not None:
                                            if len(transcription.shape) > 1:
                                                record["Transcription"] = transcription[i]
                                            else:
                                                record["Transcription"] = transcription[i] if i < len(transcription) else None
                                        
                                        target_list.append(record)
                                    
                                    print(f"        Added {num_samples} records from {trial}")
                                            
                        except Exception as e:
                            print(f"    Error processing file {file.name}: {e}")

# Create DataFrames from the collected records
print("\nCreating DataFrames...")
df_train = pd.DataFrame(train_records)
df_test = pd.DataFrame(test_records)
df_validation = pd.DataFrame(validation_records)

# Display summary for each category
print("\n=== Summary of Data ===")
print(f"Train data: {len(df_train)} records")
print(f"Test data: {len(df_test)} records")
print(f"Validation data: {len(df_validation)} records")

# Save each category to separate CSV files
if not df_train.empty:
    # Create a version without the potentially large data arrays for CSV export
    df_train_meta = df_train[['Category', 'Folder', 'File', 'Trial', 'Sample_Index']]
    df_train_meta.to_csv("train_data_summary.csv", index=False)
    print("Saved train data summary")
    
if not df_test.empty:
    df_test_meta = df_test[['Category', 'Folder', 'File', 'Trial', 'Sample_Index']]
    df_test_meta.to_csv("test_data_summary.csv", index=False)
    print("Saved test data summary")
    
if not df_validation.empty:
    df_validation_meta = df_validation[['Category', 'Folder', 'File', 'Trial', 'Sample_Index']]
    df_validation_meta.to_csv("validation_data_summary.csv", index=False)
    print("Saved validation data summary")

# Display preview of each DataFrame if not empty
if not df_train.empty:
    print("\nTrain data preview:")
    preview_cols = ['Folder', 'File', 'Trial', 'Sample_Index']
    if 'Input_Features' in df_train.columns:
        print("Input_Features shape:", df_train['Input_Features'].iloc[0].shape if hasattr(df_train['Input_Features'].iloc[0], 'shape') else 'scalar')
    if 'Seq_Class_IDs' in df_train.columns:
        print("Seq_Class_IDs shape:", df_train['Seq_Class_IDs'].iloc[0].shape if hasattr(df_train['Seq_Class_IDs'].iloc[0], 'shape') else 'scalar')
    if 'Transcription' in df_train.columns:
        print("Transcription shape:", df_train['Transcription'].iloc[0].shape if hasattr(df_train['Transcription'].iloc[0], 'shape') else 'scalar')
    print(df_train[preview_cols].head(5))
    
if not df_test.empty:
    print("\nTest data preview:")
    preview_cols = ['Folder', 'File', 'Trial', 'Sample_Index']
    if 'Input_Features' in df_test.columns:
        print("Input_Features shape:", df_test['Input_Features'].iloc[0].shape if hasattr(df_test['Input_Features'].iloc[0], 'shape') else 'scalar')
    if 'Seq_Class_IDs' in df_test.columns:
        print("Seq_Class_IDs shape:", df_test['Seq_Class_IDs'].iloc[0].shape if hasattr(df_test['Seq_Class_IDs'].iloc[0], 'shape') else 'scalar')
    if 'Transcription' in df_test.columns:
        print("Transcription shape:", df_test['Transcription'].iloc[0].shape if hasattr(df_test['Transcription'].iloc[0], 'shape') else 'scalar')
    print(df_test[preview_cols].head(5))
    
if not df_validation.empty:
    print("\nValidation data preview:")
    preview_cols = ['Folder', 'File', 'Trial', 'Sample_Index']
    if 'Input_Features' in df_validation.columns:
        print("Input_Features shape:", df_validation['Input_Features'].iloc[0].shape if hasattr(df_validation['Input_Features'].iloc[0], 'shape') else 'scalar')
    if 'Seq_Class_IDs' in df_validation.columns:
        print("Seq_Class_IDs shape:", df_validation['Seq_Class_IDs'].iloc[0].shape if hasattr(df_validation['Seq_Class_IDs'].iloc[0], 'shape') else 'scalar')
    if 'Transcription' in df_validation.columns:
        print("Transcription shape:", df_validation['Transcription'].iloc[0].shape if hasattr(df_validation['Transcription'].iloc[0], 'shape') else 'scalar')
    print(df_validation[preview_cols].head(5))

# Optionally, save the full DataFrames with data (might be large)
# df_train.to_pickle("train_data_full.pkl")
# df_test.to_pickle("test_data_full.pkl")
# df_validation.to_pickle("validation_data_full.pkl")
# Out:
# Processing folder: t15.2023.08.11
#   Processing file: data_train.hdf5
#     Categorized as: train
#     Found 288 trial groups
#       Processing trial_0000
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 321 records from trial_0000
#       Processing trial_0001
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 481 records from trial_0001
#       Processing trial_0002
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 480 records from trial_0002
#       Processing trial_0003
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 502 records from trial_0003
#       Processing trial_0004
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 402 records from trial_0004
#       Processing trial_0005
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 575 records from trial_0005
#       Processing trial_0006
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 890 records from trial_0006
#       Processing trial_0007
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 589 records from trial_0007
#       Processing trial_0008
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 445 records from trial_0008
#       Processing trial_0009
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 414 records from trial_0009
#       Processing trial_0010
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 827 records from trial_0010
#       Processing trial_0011
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 566 records from trial_0011
#       Processing trial_0012
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 331 records from trial_0012
#       Processing trial_0013
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 565 records from trial_0013
#       Processing trial_0014
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 423 records from trial_0014
#       Processing trial_0015
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 530 records from trial_0015
#       Processing trial_0016
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 424 records from trial_0016
#       Processing trial_0017
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 743 records from trial_0017
#       Processing trial_0018
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 539 records from trial_0018
#       Processing trial_0019
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 623 records from trial_0019
#       Processing trial_0020
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 138 records from trial_0020
#       Processing trial_0021
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 370 records from trial_0021
#       Processing trial_0022
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 543 records from trial_0022
#       Processing trial_0023
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 485 records from trial_0023
#       Processing trial_0024
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 635 records from trial_0024
#       Processing trial_0025
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 387 records from trial_0025
#       Processing trial_0026
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 500 records from trial_0026
#       Processing trial_0027
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 475 records from trial_0027
#       Processing trial_0028
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 606 records from trial_0028
#       Processing trial_0029
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 406 records from trial_0029
#       Processing trial_0030
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 360 records from trial_0030
#       Processing trial_0031
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 692 records from trial_0031
#       Processing trial_0032
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 264 records from trial_0032
#       Processing trial_0033
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 581 records from trial_0033
#       Processing trial_0034
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1023 records from trial_0034
#       Processing trial_0035
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 612 records from trial_0035
#       Processing trial_0036
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 774 records from trial_0036
#       Processing trial_0037
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 414 records from trial_0037
#       Processing trial_0038
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 607 records from trial_0038
#       Processing trial_0039
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 452 records from trial_0039
#       Processing trial_0040
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 572 records from trial_0040
#       Processing trial_0041
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 428 records from trial_0041
#       Processing trial_0042
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 390 records from trial_0042
#       Processing trial_0043
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 285 records from trial_0043
#       Processing trial_0044
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 711 records from trial_0044
#       Processing trial_0045
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 699 records from trial_0045
#       Processing trial_0046
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 616 records from trial_0046
#       Processing trial_0047
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 553 records from trial_0047
#       Processing trial_0048
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 525 records from trial_0048
#       Processing trial_0049
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 434 records from trial_0049
#       Processing trial_0050
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 402 records from trial_0050
#       Processing trial_0051
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 491 records from trial_0051
#       Processing trial_0052
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 440 records from trial_0052
#       Processing trial_0053
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 380 records from trial_0053
#       Processing trial_0054
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 523 records from trial_0054
#       Processing trial_0055
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 902 records from trial_0055
#       Processing trial_0056
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 322 records from trial_0056
#       Processing trial_0057
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 550 records from trial_0057
#       Processing trial_0058
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 369 records from trial_0058
#       Processing trial_0059
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 592 records from trial_0059
#       Processing trial_0060
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 379 records from trial_0060
#       Processing trial_0061
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 470 records from trial_0061
#       Processing trial_0062
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 522 records from trial_0062
#       Processing trial_0063
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 413 records from trial_0063
#       Processing trial_0064
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 842 records from trial_0064
#       Processing trial_0065
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 380 records from trial_0065
#       Processing trial_0066
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 508 records from trial_0066
#       Processing trial_0067
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 602 records from trial_0067
#       Processing trial_0068
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 613 records from trial_0068
#       Processing trial_0069
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 592 records from trial_0069
#       Processing trial_0070
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 607 records from trial_0070
#       Processing trial_0071
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 525 records from trial_0071
#       Processing trial_0072
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 773 records from trial_0072
#       Processing trial_0073
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 616 records from trial_0073
#       Processing trial_0074
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 322 records from trial_0074
#       Processing trial_0075
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 495 records from trial_0075
#       Processing trial_0076
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 619 records from trial_0076
#       Processing trial_0077
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 532 records from trial_0077
#       Processing trial_0078
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 468 records from trial_0078
#       Processing trial_0079
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 746 records from trial_0079
#       Processing trial_0080
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 656 records from trial_0080
#       Processing trial_0081
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 482 records from trial_0081
#       Processing trial_0082
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 439 records from trial_0082
#       Processing trial_0083
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 808 records from trial_0083
#       Processing trial_0084
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 500 records from trial_0084
#       Processing trial_0085
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 530 records from trial_0085
#       Processing trial_0086
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 923 records from trial_0086
#       Processing trial_0087
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 484 records from trial_0087
#       Processing trial_0088
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 680 records from trial_0088
#       Processing trial_0089
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 671 records from trial_0089
#       Processing trial_0090
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 288 records from trial_0090
#       Processing trial_0091
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 360 records from trial_0091
#       Processing trial_0092
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 438 records from trial_0092
#       Processing trial_0093
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 467 records from trial_0093
#       Processing trial_0094
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 471 records from trial_0094
#       Processing trial_0095
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 667 records from trial_0095
#       Processing trial_0096
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 667 records from trial_0096
#       Processing trial_0097
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 457 records from trial_0097
#       Processing trial_0098
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 617 records from trial_0098
#       Processing trial_0099
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 515 records from trial_0099
#       Processing trial_0100
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 367 records from trial_0100
#       Processing trial_0101
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 679 records from trial_0101
#       Processing trial_0102
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 389 records from trial_0102
#       Processing trial_0103
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 588 records from trial_0103
#       Processing trial_0104
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 529 records from trial_0104
#       Processing trial_0105
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 411 records from trial_0105
#       Processing trial_0106
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 572 records from trial_0106
#       Processing trial_0107
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 681 records from trial_0107
#       Processing trial_0108
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 402 records from trial_0108
#       Processing trial_0109
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 487 records from trial_0109
#       Processing trial_0110
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 627 records from trial_0110
#       Processing trial_0111
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 396 records from trial_0111
#       Processing trial_0112
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 356 records from trial_0112
#       Processing trial_0113
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 701 records from trial_0113
#       Processing trial_0114
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 563 records from trial_0114
#       Processing trial_0115
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 467 records from trial_0115
#       Processing trial_0116
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 426 records from trial_0116
#       Processing trial_0117
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 518 records from trial_0117
#       Processing trial_0118
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 553 records from trial_0118
#       Processing trial_0119
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 620 records from trial_0119
#       Processing trial_0120
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 518 records from trial_0120
#       Processing trial_0121
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 585 records from trial_0121
#       Processing trial_0122
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 528 records from trial_0122
#       Processing trial_0123
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 421 records from trial_0123
#       Processing trial_0124
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 854 records from trial_0124
#       Processing trial_0125
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 581 records from trial_0125
#       Processing trial_0126
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 426 records from trial_0126
#       Processing trial_0127
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 726 records from trial_0127
#       Processing trial_0128
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 503 records from trial_0128
#       Processing trial_0129
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 390 records from trial_0129
#       Processing trial_0130
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 481 records from trial_0130
#       Processing trial_0131
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 713 records from trial_0131
#       Processing trial_0132
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 623 records from trial_0132
#       Processing trial_0133
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 282 records from trial_0133
#       Processing trial_0134
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 545 records from trial_0134
#       Processing trial_0135
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 791 records from trial_0135
#       Processing trial_0136
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 674 records from trial_0136
#       Processing trial_0137
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 383 records from trial_0137
#       Processing trial_0138
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 601 records from trial_0138
#       Processing trial_0139
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 593 records from trial_0139
#       Processing trial_0140
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 320 records from trial_0140
#       Processing trial_0141
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 585 records from trial_0141
#       Processing trial_0142
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 867 records from trial_0142
#       Processing trial_0143
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 385 records from trial_0143
#       Processing trial_0144
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 926 records from trial_0144
#       Processing trial_0145
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 406 records from trial_0145
#       Processing trial_0146
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 835 records from trial_0146
#       Processing trial_0147
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 785 records from trial_0147
#       Processing trial_0148
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 500 records from trial_0148
#       Processing trial_0149
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1001 records from trial_0149
#       Processing trial_0150
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 527 records from trial_0150
#       Processing trial_0151
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 577 records from trial_0151
#       Processing trial_0152
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 523 records from trial_0152
#       Processing trial_0153
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 582 records from trial_0153
#       Processing trial_0154
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 905 records from trial_0154
#       Processing trial_0155
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 475 records from trial_0155
#       Processing trial_0156
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 543 records from trial_0156
#       Processing trial_0157
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 602 records from trial_0157
#       Processing trial_0158
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 290 records from trial_0158
#       Processing trial_0159
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 549 records from trial_0159
#       Processing trial_0160
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 420 records from trial_0160
#       Processing trial_0161
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 482 records from trial_0161
#       Processing trial_0162
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 694 records from trial_0162
#       Processing trial_0163
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 423 records from trial_0163
#       Processing trial_0164
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 540 records from trial_0164
#       Processing trial_0165
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 513 records from trial_0165
#       Processing trial_0166
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 298 records from trial_0166
#       Processing trial_0167
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 501 records from trial_0167
#       Processing trial_0168
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 913 records from trial_0168
#       Processing trial_0169
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 402 records from trial_0169
#       Processing trial_0170
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 415 records from trial_0170
#       Processing trial_0171
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 600 records from trial_0171
#       Processing trial_0172
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 650 records from trial_0172
#       Processing trial_0173
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 525 records from trial_0173
#       Processing trial_0174
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 534 records from trial_0174
#       Processing trial_0175
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 604 records from trial_0175
#       Processing trial_0176
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 526 records from trial_0176
#       Processing trial_0177
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 702 records from trial_0177
#       Processing trial_0178
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 484 records from trial_0178
#       Processing trial_0179
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 596 records from trial_0179
#       Processing trial_0180
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 422 records from trial_0180
#       Processing trial_0181
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 597 records from trial_0181
#       Processing trial_0182
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 627 records from trial_0182
#       Processing trial_0183
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 408 records from trial_0183
#       Processing trial_0184
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 309 records from trial_0184
#       Processing trial_0185
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 566 records from trial_0185
#       Processing trial_0186
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 677 records from trial_0186
#       Processing trial_0187
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 530 records from trial_0187
#       Processing trial_0188
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 459 records from trial_0188
#       Processing trial_0189
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 283 records from trial_0189
#       Processing trial_0190
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 379 records from trial_0190
#       Processing trial_0191
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 464 records from trial_0191
#       Processing trial_0192
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 378 records from trial_0192
#       Processing trial_0193
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 385 records from trial_0193
#       Processing trial_0194
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 386 records from trial_0194
#       Processing trial_0195
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 778 records from trial_0195
#       Processing trial_0196
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 561 records from trial_0196
#       Processing trial_0197
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 370 records from trial_0197
#       Processing trial_0198
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 473 records from trial_0198
#       Processing trial_0199
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 431 records from trial_0199
#       Processing trial_0200
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 447 records from trial_0200
#       Processing trial_0201
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 757 records from trial_0201
#       Processing trial_0202
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 508 records from trial_0202
#       Processing trial_0203
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 605 records from trial_0203
#       Processing trial_0204
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 359 records from trial_0204
#       Processing trial_0205
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 606 records from trial_0205
#       Processing trial_0206
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 428 records from trial_0206
#       Processing trial_0207
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 301 records from trial_0207
#       Processing trial_0208
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 365 records from trial_0208
#       Processing trial_0209
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 248 records from trial_0209
#       Processing trial_0210
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 464 records from trial_0210
#       Processing trial_0211
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 449 records from trial_0211
#       Processing trial_0212
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 386 records from trial_0212
#       Processing trial_0213
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 573 records from trial_0213
#       Processing trial_0214
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 743 records from trial_0214
#       Processing trial_0215
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 482 records from trial_0215
#       Processing trial_0216
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 391 records from trial_0216
#       Processing trial_0217
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 652 records from trial_0217
#       Processing trial_0218
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 711 records from trial_0218
#       Processing trial_0219
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 531 records from trial_0219
#       Processing trial_0220
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 457 records from trial_0220
#       Processing trial_0221
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 782 records from trial_0221
#       Processing trial_0222
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 370 records from trial_0222
#       Processing trial_0223
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 831 records from trial_0223
#       Processing trial_0224
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 662 records from trial_0224
#       Processing trial_0225
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 638 records from trial_0225
#       Processing trial_0226
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 557 records from trial_0226
#       Processing trial_0227
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 446 records from trial_0227
#       Processing trial_0228
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 415 records from trial_0228
#       Processing trial_0229
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 526 records from trial_0229
#       Processing trial_0230
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 634 records from trial_0230
#       Processing trial_0231
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 421 records from trial_0231
#       Processing trial_0232
#         Found input features: input_features
# ...
#         Found transcription: transcription
#         Added 1337 records from trial_0024
#       Processing trial_0025
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 740 records from trial_0025
#       Processing trial_0026
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 921 records from trial_0026
#       Processing trial_0027
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 927 records from trial_0027
#       Processing trial_0028
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 705 records from trial_0028
#       Processing trial_0029
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 636 records from trial_0029
#       Processing trial_0030
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 968 records from trial_0030
#       Processing trial_0031
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 892 records from trial_0031
#       Processing trial_0032
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 818 records from trial_0032
#       Processing trial_0033
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 571 records from trial_0033
#       Processing trial_0034
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 770 records from trial_0034
#       Processing trial_0035
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1041 records from trial_0035
#       Processing trial_0036
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1594 records from trial_0036
#       Processing trial_0037
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 662 records from trial_0037
#       Processing trial_0038
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 843 records from trial_0038
#       Processing trial_0039
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1121 records from trial_0039
#       Processing trial_0040
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 773 records from trial_0040
#       Processing trial_0041
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 781 records from trial_0041
#       Processing trial_0042
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 972 records from trial_0042
#       Processing trial_0043
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1193 records from trial_0043
#       Processing trial_0044
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 691 records from trial_0044
#       Processing trial_0045
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 921 records from trial_0045
#       Processing trial_0046
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 627 records from trial_0046
#       Processing trial_0047
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1082 records from trial_0047
#       Processing trial_0048
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 693 records from trial_0048
#       Processing trial_0049
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 889 records from trial_0049
#       Processing trial_0050
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 962 records from trial_0050
#       Processing trial_0051
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 970 records from trial_0051
#       Processing trial_0052
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 752 records from trial_0052
#       Processing trial_0053
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 918 records from trial_0053
#       Processing trial_0054
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 664 records from trial_0054
#       Processing trial_0055
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 780 records from trial_0055
#       Processing trial_0056
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1369 records from trial_0056
#       Processing trial_0057
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 821 records from trial_0057
#       Processing trial_0058
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1219 records from trial_0058
#       Processing trial_0059
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 785 records from trial_0059
#       Processing trial_0060
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 875 records from trial_0060
#       Processing trial_0061
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 795 records from trial_0061
#       Processing trial_0062
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 946 records from trial_0062
#       Processing trial_0063
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1010 records from trial_0063
#       Processing trial_0064
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 997 records from trial_0064
#       Processing trial_0065
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 715 records from trial_0065
#       Processing trial_0066
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 860 records from trial_0066
#       Processing trial_0067
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 802 records from trial_0067
#       Processing trial_0068
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 690 records from trial_0068
#   Processing file: data_val.hdf5
#     Categorized as: validation
#     Found 25 trial groups
#       Processing trial_0000
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1011 records from trial_0000
#       Processing trial_0001
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 948 records from trial_0001
#       Processing trial_0002
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 902 records from trial_0002
#       Processing trial_0003
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 798 records from trial_0003
#       Processing trial_0004
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 641 records from trial_0004
#       Processing trial_0005
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 560 records from trial_0005
#       Processing trial_0006
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 762 records from trial_0006
#       Processing trial_0007
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 847 records from trial_0007
#       Processing trial_0008
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1171 records from trial_0008
#       Processing trial_0009
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1345 records from trial_0009
#       Processing trial_0010
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 669 records from trial_0010
#       Processing trial_0011
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1139 records from trial_0011
#       Processing trial_0012
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 723 records from trial_0012
#       Processing trial_0013
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1027 records from trial_0013
#       Processing trial_0014
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 963 records from trial_0014
#       Processing trial_0015
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 933 records from trial_0015
#       Processing trial_0016
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1424 records from trial_0016
#       Processing trial_0017
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1064 records from trial_0017
#       Processing trial_0018
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 944 records from trial_0018
#       Processing trial_0019
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 602 records from trial_0019
#       Processing trial_0020
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 995 records from trial_0020
#       Processing trial_0021
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 794 records from trial_0021
#       Processing trial_0022
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1183 records from trial_0022
#       Processing trial_0023
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 1142 records from trial_0023
#       Processing trial_0024
#         Found input features: input_features
#         Found sequence class IDs: seq_class_ids
#         Found transcription: transcription
#         Added 969 records from trial_0024
#
# Creating DataFrames...
#
# === Summary of Data ===
# Train data: 7061713 records
# Test data: 1329030 records
# Validation data: 1314955 records
# Saved train data summary
# Saved test data summary
# Saved validation data summary
#
# Train data preview:
# Input_Features shape: (512,)
# Seq_Class_IDs shape: ()
# Transcription shape: ()
#            Folder             File       Trial  Sample_Index
# 0  t15.2023.08.11  data_train.hdf5  trial_0000             0
# 1  t15.2023.08.11  data_train.hdf5  trial_0000             1
# 2  t15.2023.08.11  data_train.hdf5  trial_0000             2
# 3  t15.2023.08.11  data_train.hdf5  trial_0000             3
# 4  t15.2023.08.11  data_train.hdf5  trial_0000             4
#
# Test data preview:
# Input_Features shape: (512,)
#            Folder            File       Trial  Sample_Index
# 0  t15.2023.08.13  data_test.hdf5  trial_0000             0
# 1  t15.2023.08.13  data_test.hdf5  trial_0000             1
# 2  t15.2023.08.13  data_test.hdf5  trial_0000             2
# 3  t15.2023.08.13  data_test.hdf5  trial_0000             3
# 4  t15.2023.08.13  data_test.hdf5  trial_0000             4
#
# Validation data preview:
# Input_Features shape: (512,)
# Seq_Class_IDs shape: ()
# Transcription shape: ()
#            Folder           File       Trial  Sample_Index
# 0  t15.2023.08.13  data_val.hdf5  trial_0000             0
# 1  t15.2023.08.13  data_val.hdf5  trial_0000             1
# 2  t15.2023.08.13  data_val.hdf5  trial_0000             2
# 3  t15.2023.08.13  data_val.hdf5  trial_0000             3
# 4  t15.2023.08.13  data_val.hdf5  trial_0000             4

# %%
print(df_train.head())
# print(df_test.head())
# Out:
#   Category          Folder             File       Trial  Sample_Index  \
# 0    train  t15.2023.08.11  data_train.hdf5  trial_0000             0
# 1    train  t15.2023.08.11  data_train.hdf5  trial_0000             1
# 2    train  t15.2023.08.11  data_train.hdf5  trial_0000             2
# 3    train  t15.2023.08.11  data_train.hdf5  trial_0000             3
# 4    train  t15.2023.08.11  data_train.hdf5  trial_0000             4
#
#                                       Input_Features  Seq_Class_IDs  \
# 0  [2.3076649, -0.78699756, -0.64687246, -0.54658...            7.0
# 1  [-0.5859305, -0.78699756, -0.64687246, -0.5465...           28.0
# 2  [-0.5859305, -0.78699756, -0.64687246, -0.5465...           17.0
# 3  [0.8608672, 1.2421287, -0.64687246, -0.5465877...           24.0
# 4  [-0.5859305, -0.78699756, -0.64687246, -0.5465...           40.0
#
#    Transcription
# 0           66.0
# 1          114.0
# 2          105.0
# 3          110.0
# 4          103.0

# %%
print(df_test.head())
# Out:
#   Category          Folder            File       Trial  Sample_Index  \
# 0     test  t15.2023.08.13  data_test.hdf5  trial_0000             0
# 1     test  t15.2023.08.13  data_test.hdf5  trial_0000             1
# 2     test  t15.2023.08.13  data_test.hdf5  trial_0000             2
# 3     test  t15.2023.08.13  data_test.hdf5  trial_0000             3
# 4     test  t15.2023.08.13  data_test.hdf5  trial_0000             4
#
#                                       Input_Features
# 0  [-0.46759456, -0.27936023, -0.40907395, -0.459...
# 1  [-0.46759456, -0.27936023, -0.40907395, -0.459...
# 2  [-0.46759456, -0.27936023, -0.40907395, -0.459...
# 3  [-0.46759456, -0.27936023, -0.40907395, -0.459...
# 4  [-0.46759456, -0.27936023, -0.40907395, -0.459...
